# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12.0, 6.0)

# STRATEGY SET UP
txCost = 0
ts = pd.read_csv('data/WallSt-hourly-all.txt', index_col=0, parse_dates=[[0, 1]], dayfirst=True )

# Resample into hourly data
#order = ts.columns
#ts = ts.resample('5min').agg({'Open': 'first', 'High': 'max', 'Low': 'min','Close': 'last'})[order]


# Remove hours we are not interested in
#ts[(ts.index.hour > 19) | (ts.index.hour < 12)] = np.nan

# Resample into Business Days
#ts = ts.resample('5min').agg({'Open': 'first', 'High': 'max', 'Low': 'min','Close': 'last'})[order]
#ts
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-431ab5409c70> in <module>()
#      10 # STRATEGY SET UP
#      11 txCost = 0
# ---> 12 ts = pd.read_csv('data/WallSt-hourly-all.txt', index_col=0, parse_dates=[[0, 1]], dayfirst=True )
#      13
#      14 # Resample into hourly data
#
# ...

# %%
from tradeFramework.api import Strategy, Portfolio, Model, TradeEnvironment
from tradeFramework.environments import SandboxEnvironment, SandboxContext, ZiplineEnvironment
from tradeFramework.models import PreOpenMomentum
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-9d58c49e9a19> in <module>()
# ----> 1 from tradeFramework.api import Strategy, Portfolio, Model, TradeEnvironment
#       2 from tradeFramework.environments import SandboxEnvironment, SandboxContext, ZiplineEnvironment
#       3 from tradeFramework.models import PreOpenMomentum
#
# ImportError: No module named tradeFramework.api

# %%
env = SandboxEnvironment("TradeFair")
context = {}

p = env.createPortfolio("MyPortfolio")
p.addModel(env.createModel( "PreOpenMomentum", "MyModel" ))
#p.addModel(env.createModel( "PreOpenMomentum", "MyModel2" ))


# Feed data into the portfolio

#for index in range(0, len(ts)):
#env.handleData(0, ts[:index+1])
allocations = env.handleData(context, ts)
#env.placeOrders(context, allocations, ts)

#print allocations
#context['portfolio_returns']

# %%
env.placeOrders(context, allocations, ts)

# %%
ret = context['portfolio_returns']

pnl = np.cumprod(ret.resample('B').agg({'Sandbox Engine': 'prod'}))

plt.plot(pnl)
plt.show() 

np.exp(np.log(ret['Sandbox Engine']).resample('B').agg({'Sandbox Engine': 'sum'}))-1
# Out:
#             Sandbox Engine
# 2016-04-19    0.0000000000
# 2016-04-20   -0.0034482701
# 2016-04-21   -0.0078815289
# 2016-04-22    0.0007448748
# 2016-04-25   -0.0002216459
# 2016-04-26   -0.0006777514
# 2016-04-27   -0.0047485374
# 2016-04-28    0.0029880593
# 2016-04-29    0.0027879990
# 2016-05-02    0.0052309836
# 2016-05-03    0.0000699353
# 2016-05-04   -0.0003329269
# 2016-05-05   -0.0033970611
# 2016-05-06   -0.0074708307
# 2016-05-09   -0.0041167075
# 2016-05-10    0.0072479647
# 2016-05-11    0.0077898311
# 2016-05-12   -0.0034524445
# 2016-05-13    0.0071113968
# 2016-05-16    0.0095142543
# 2016-05-17    0.0100653862
# 2016-05-18   -0.0011939318
# 2016-05-19    0.0008941791
# 2016-05-20    0.0011041443
# 2016-05-23   -0.0006392107
# 2016-05-24    0.0090459308
# 2016-05-25    0.0041634316
# 2016-05-26   -0.0026800201
# 2016-05-27    0.0008121156
# 2016-05-30    0.0000502426
# ...                    ...
# 2016-09-29    0.0095657360
# 2016-09-30    0.0071524855
# ...
